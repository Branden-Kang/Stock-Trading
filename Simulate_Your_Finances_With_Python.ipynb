# %% [markdown]
# [Reference](https://levelup.gitconnected.com/simulate-your-finances-with-python-7155f1f8e1c7)

# %%
pip install pylan-lib
# Out:
# Collecting pylan-lib
#   Downloading pylan_lib-0.1.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from pylan-lib) (2.8.2)
# Collecting cron-converter (from pylan-lib)
#   Downloading cron_converter-1.2.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->pylan-lib) (1.17.0)
# Downloading pylan_lib-0.1.4-py3-none-any.whl (10 kB)
# Downloading cron_converter-1.2.1-py3-none-any.whl (13 kB)
# Installing collected packages: cron-converter, pylan-lib
# Successfully installed cron-converter-1.2.1 pylan-lib-0.1.4

# %%
import matplotlib.pyplot as plt

from pylan import Item, Subtract, Add, Multiply

# %%
savings = Item(start_value=100)
salary_payments = Add("1m", 2500, offset="24d") # Salary paid every month at the 24th
salary_increase = Multiply("1y", 1.2) # Salary grows each year 20%
mortgage = Subtract("0 0 2 * *", 1500)  # cron support

salary_payments.add_pattern(salary_increase) # Add increase to salary pattern
savings.add_patterns([salary_payments, mortgage])
result = savings.run("2024-1-1", "2028-1-1")

x, y = result.plot_axes()

plt.plot(x, y)
plt.show()
